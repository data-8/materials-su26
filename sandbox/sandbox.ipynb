# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
""" 
Names of tables:

world_population.csv
actors.csv
age.csv
baby.csv
banknote.csv
boston.csv
breast-cancer.csv
bta.csv
burrito.csv
burritos_types.csv
cal_fb.csv
child_mortality.csv
city_info.csv
ckd.csv
cones.csv
coordinates.csv
countries.csv
district_demographics2016.csv
du_bois.csv
dugong.csv
exams_fa18.csv
faithful.csv
family_heights.csv
farmers_markets.csv
fertility.csv
fifa22.csv
friend_movies.csv
happiness_scores.csv
house.csv
hybrid.csv
imdb.csv
inventory.csv
life_expectancy.csv
manila.csv
marbles.csv
more_restaurant_bills.csv
movies_by_year.csv
movies.csv
nba_salaries.csv
nba.csv
nc-est2019-agesex-res.csv
nst-est2016-alldata.csv
old_faithful.csv
phoenix 2.csv
phoenix.csv
population.csv
poverty.csv
president_births.csv
ratings.csv
raw_compensation.csv
roulette_wheel.csv
sales.csv
san_francisco_2019.csv
sandbox.ipynb
sat_scores.csv
sat2014.csv
scores_by_section.csv
sf_salaries_2023.csv
sf2019.csv
shotput.csv
skyscrapers.csv
snowy_plover.csv
southwest.csv
star_bakers.csv
stem.csv
temperatures.csv
top_movies_2017.csv
unemployment.csv
united.csv
us_happiness_factors.csv
us_women.csv
votes.csv
welcome_survey_fa22.csv
welcome_survey_sp24.csv
welcome_survey_sp25.csv
welcome_survey_sp26.csv
"""

# %%
my_table = Table.read_table('welcome_survey_sp26.csv')

# %%
my_table.where('Languages', are.above(0)).group('Languages')
# Out:
# Languages | count
# 1         | 86
# 2         | 334
# 3         | 320
# 4         | 128
# 5         | 73
# 6         | 22
# 7         | 27
# 8         | 9
# 10        | 3

# %%
my_table.where('Languages', are.above(0)).group('Languages')

# %%
my_table = Table.read_table('welcome_survey_sp26.csv')
my_table.where('Languages', are.above(0)).hist('Languages', bins = make_array(0, 2, 5, 8, 11), unit='number spoken')

# %%
staff = make_array("Soumyadeep", "Cynthia", "Tai", "Elizabeth", "Nao", "Richard", "Viraj", "Raghavan", "Lena")

# %%
np.random.choice(staff,size=1)
# Out:
# array(['Soumyadeep'],
#       dtype='<U10')
