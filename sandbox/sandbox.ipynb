# %% [markdown]
# <img src="data8logo.png" alt="Data 8 Logo" style="width: 15%; float: right; padding: 1%; margin-right: 2%;"/>
#
# # Data 8 Sandbox 🪏
#
# Welcome to the Data 8: *Foundations of Data Science* sandbox! This is your space to get hands-on practice programming with Python and the `datascience` library.
#
# Here are some helpful links:
# - [Python Reference](https://data8.org/su26/reference/)
# - [datascience documentation](https://data8.org/datascience/index.html)
#
# Have fun coding!

# %%
# Run this cell to import necessary libraries.
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Click "Open in..." at the top right corner, and select "JupyterLab" to view this notebook in JupyterLab, which allows you to browse the various CSV files!
# </div>

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Tables

# %% [markdown]
# Names of tables:
#
# - `actors.csv`
# - `age.csv`
# - `baby.csv`
# - `banknote.csv`
# - `boston.csv`
# - `breast-cancer.csv`
# - `bta.csv`
# - `burrito.csv`
# - `burritos_types.csv`
# - `cal_fb.csv`
# - `child_mortality.csv`
# - `city_info.csv`
# - `ckd.csv`
# - `cones.csv`
# - `coordinates.csv`
# - `countries.csv`
# - `district_demographics2016.csv`
# - `du_bois.csv`
# - `dugong.csv`
# - `exams_fa18.csv`
# - `faithful.csv`
# - `family_heights.csv`
# - `farmers_markets.csv`
# - `fertility.csv`
# - `fifa22.csv`
# - `friend_movies.csv`
# - `happiness_scores.csv`
# - `house.csv`
# - `hybrid.csv`
# - `imdb.csv`
# - `inventory.csv`
# - `life_expectancy.csv`
# - `manila.csv`
# - `marbles.csv`
# - `more_restaurant_bills.csv`
# - `movies_by_year.csv`
# - `movies.csv`
# - `nba_salaries.csv`
# - `nba.csv`
# - `nc-est2019-agesex-res.csv`
# - `nst-est2016-alldata.csv`
# - `old_faithful.csv`
# - `phoenix 2.csv`
# - `phoenix.csv`
# - `population.csv`
# - `poverty.csv`
# - `president_births.csv`
# - `ratings.csv`
# - `raw_compensation.csv`
# - `roulette_wheel.csv`
# - `sales.csv`
# - `san_francisco_2019.csv`
# - `sandbox.ipynb`
# - `sat_scores.csv`
# - `sat2014.csv`
# - `scores_by_section.csv`
# - `sf_salaries_2023.csv`
# - `sf2019.csv`
# - `shotput.csv`
# - `skyscrapers.csv`
# - `snowy_plover.csv`
# - `southwest.csv`
# - `star_bakers.csv`
# - `stem.csv`
# - `temperatures.csv`
# - `top_movies_2017.csv`
# - `unemployment.csv`
# - `united.csv`
# - `us_happiness_factors.csv`
# - `us_women.csv`
# - `votes.csv`
# - `welcome_survey_fa22.csv`
# - `welcome_survey_sp24.csv`
# - `welcome_survey_sp25.csv`
# - `welcome_survey_sp26.csv`
# - `world_population.csv`

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Code

# %%
# Replace 'actors.csv' with the filename of the table you'd like to work with!
my_table = Table.read_table('actors.csv')

# %%
my_table.show()
